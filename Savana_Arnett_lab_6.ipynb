# %% [markdown]
# <a href="https://colab.research.google.com/github/Savanaarnett/Data_science/blob/main/Savana_Arnett_lab_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Always start off w/ importing numpy.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import urllib.request

# %%
#added new request

# %%
url = 'https://raw.githubusercontent.com/williamedwardhahn/Probability_Statistics/main/cereal_data.csv'

# %%
#This url contains the url for data that was uploaded to the github

# %%
urllib.request.urlretrieve('https://raw.githubusercontent.com/williamedwardhahn/Probability_Statistics/main/cereal_data.csv','cereal_data.csv')
# Out:
# ('cereal_data.csv', <http.client.HTTPMessage at 0x7f0e4af70e50>)

# %%
#This command requests the data to be brought into the program.

# %%
cereal_data = pd.read_csv('cereal_data.csv')

# %%
#This is giving the command a direct name, so everytime you input cereal_data it will bring up the data.

# %%
cereal_data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
#By imputing "sugars" the program only brings up the sugar data.

# %%
cereal_data["sugars"]
# Out:
# 0      6
# 1      8
# 2      5
# 3      0
# 4      8
#       ..
# 72     3
# 73    12
# 74     3
# 75     3
# 76     8
# Name: sugars, Length: 77, dtype: int64

# %%
#Since "calories" was added it brings up the calorie and sugar data.

# %%
cereal_data[["calories","sugars"]]
# Out:
#     calories  sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 72       110       3
# 73       110      12
# 74       100       3
# 75       100       3
# 76       110       8
#
# [77 rows x 2 columns]

# %%
#By adding the ".mean" it allows for the program to calculate the mean of the data in that category.

# %%
cereal_data["sugars"].mean()
# Out:
# 6.922077922077922

# %%
#This calculated the means of both calories and sugar.

# %%
cereal_data[["calories", "sugars"]].mean()
# Out:
# calories    106.883117
# sugars        6.922078
# dtype: float64

# %%
#By putting "plt.plot" this allows for the selected data to be plotted on a graph.

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["calories"]],'.')

# %%
x = cereal_data[["sugars"]]
y = cereal_data[["calories"]]

plt.plot(x,y,'.')

# %%
#The last line specifies that it should plot the points and not connect them.

# %%
x = cereal_data[["sugars"]]
y = cereal_data[["calories"]]

plt.plot(x,y,'.')
plt.xlabel("sugars")
plt.ylabel("calories")
plt.title("sugars vs calories");

# %%
#The last few lines of the fubnction add the titles along the edges of the graph.

# %%
x = cereal_data[["sugars"]]
y = cereal_data[["calories"]]

plt.plot(x,y,'.')
plt.xlabel("Fat")
plt.ylabel("Calories")
plt.title("Fat vs Calories");

# %%
x = cereal_data[["sugars"]]
y = cereal_data[["calories"]]

plt.plot(x,y,'.')
plt.xlabel("Sugars")
plt.ylabel("Rating")
plt.title("Sugars vs Rating");

# %%
X = cereal_data[["sugars"]]
Y = cereal_data[["calories"]]

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()

# %%
#Importing this program allows for the linear of best fit to be predicted within the graphed data. As shown with the red line below.

# %%
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)

# %%
plt.plot(X, Y,'.')
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
x = np.linspace(0,10,50)

# %%
#This array lists all of the possibilities within the data.

# %%
x
# Out:
# array([ 0.        ,  0.20408163,  0.40816327,  0.6122449 ,  0.81632653,
#         1.02040816,  1.2244898 ,  1.42857143,  1.63265306,  1.83673469,
#         2.04081633,  2.24489796,  2.44897959,  2.65306122,  2.85714286,
#         3.06122449,  3.26530612,  3.46938776,  3.67346939,  3.87755102,
#         4.08163265,  4.28571429,  4.48979592,  4.69387755,  4.89795918,
#         5.10204082,  5.30612245,  5.51020408,  5.71428571,  5.91836735,
#         6.12244898,  6.32653061,  6.53061224,  6.73469388,  6.93877551,
#         7.14285714,  7.34693878,  7.55102041,  7.75510204,  7.95918367,
#         8.16326531,  8.36734694,  8.57142857,  8.7755102 ,  8.97959184,
#         9.18367347,  9.3877551 ,  9.59183673,  9.79591837, 10.        ])

# %%
m = 3
b = 7

y = m* x + b

# %%
noise = 10 * np.random.randn(50,)

# %%
y = m * x + b + noise

# %%
#This plotted the function above.

# %%
plt.plot(x,y,'.')

# %%
m_guess = 1
b_guess = 1

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
m_guess = 5
b_guess = 15

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

# %%
loss = np.sum((y_guess - y)**2)

# %%
#This graphs the multiple possibilities within the data.

# %%
for m_guess in np.linspace(-10,10,10):
    for b_guess in np.linspace(-10,10,10):
        
        y_guess = m_guess * x + b_guess

        plt.plot(x,y_guess,'r.');
        plt.plot(x,y,'g.');
        plt.show()

        loss = np.sum((y_guess - y)**2)

        print(loss,m_guess,b_guess)
# Out:
# 437136.7258212591 -10.0 -10.0
# 418525.30490145163 -10.0 -7.777777777777778
# 400407.7111421381 -10.0 -5.555555555555555
# 382783.94454331824 -10.0 -3.333333333333333
# 365654.0051049923 -10.0 -1.1111111111111107
# 349017.89282716013 -10.0 1.1111111111111107
# 332875.60770982184 -10.0 3.333333333333334
# 317227.14975297736 -10.0 5.555555555555557
# 302072.51895662665 -10.0 7.777777777777779
# 287411.7153207699 -10.0 10.0
# 326193.83416697977 -7.777777777777778 -10.0
# 310051.5490496415 -7.777777777777778 -7.777777777777778
# 294403.09109279705 -7.777777777777778 -5.555555555555555
# 279248.4602964463 -7.777777777777778 -3.333333333333333
# 264587.6566605895 -7.777777777777778 -1.1111111111111107
# 250420.6801852265 -7.777777777777778 1.1111111111111107
# 236747.53087035732 -7.777777777777778 3.333333333333334
# 223568.20871598195 -7.777777777777778 5.555555555555557
# 210882.71372210045 -7.777777777777778 7.777777777777779
# 198691.04588871278 -7.777777777777778 10.0
# ...

# %%
#This coding will bring up multiple combinations of the info input.

# %%
best_loss = 100000
best_m = 0
best_b = 0 

for m_guess in np.linspace(-10,10,20):
    for b_guess in np.linspace(-10,10,20):
        
        y_guess = m_guess * x + b_guess

        loss = np.sum((y_guess - y)**2)

        if loss < best_loss:
            
            best_loss = loss
            best_m = m_guess
            best_b = b_guess 

            plt.plot(x,y_guess,'r.');
            plt.plot(x,y,'g.');
            plt.show()

            print(loss,m_guess,b_guess)
# Out:
# 97690.81469623139 -3.6842105263157894 4.7368421052631575
# 93688.66732916962 -3.6842105263157894 5.789473684210526
# 89797.32328620757 -3.6842105263157894 6.842105263157894
# 86016.78256734526 -3.6842105263157894 7.894736842105264
# 82347.04517258267 -3.6842105263157894 8.94736842105263
# 78788.1111019198 -3.6842105263157894 10.0
# 76768.02815872685 -2.6315789473684212 3.6842105263157894
# 73209.09408806398 -2.6315789473684212 4.7368421052631575
# 69760.96334150084 -2.6315789473684212 5.789473684210526
# 66423.63591903742 -2.6315789473684212 6.842105263157894
# 63197.11182067371 -2.6315789473684212 7.894736842105264
# 60081.39104640974 -2.6315789473684212 8.94736842105263
# 57076.47359624549 -2.6315789473684212 10.0
# 55463.423272194384 -1.578947368421053 3.6842105263157894
# 52458.505822030136 -1.578947368421053 4.7368421052631575
# 49564.3916959656 -1.578947368421053 5.789473684210526
# 46781.080894000785 -1.578947368421053 6.842105263157894
# ...
